# %% [markdown]
# ## Reinforcement Learning Tutorial -2: DQN

# %% [markdown]
# ### MD Muhaimin Rahman
# contact: sezan92[at]gmail[dot]com

# %% [markdown]
# In our last tutorial, I tried to explain Q-learning algorithm. The biggest problem with Q-learning is that,it only takes discrete inputs and outputs discrete values. In the Mountain Car problem, we solved this issue by discretizing states which are actually continuous. But this can't be done always. Specially when the states are multidimensional states or images. Deep learning comes here to solve this problem!

# %% [markdown]
# In this project, I have worked on Deep Q Learning . This is the first part which solves the problem of [Cart Pole](https://github.com/openai/gym/wiki/CartPole-v0) by ```Open AI``` Gym. The concept is based on the ground breaking [work](https://arxiv.org/pdf/1312.5602.pdf) of Deep Mind. The CartPole video is available [here](https://youtu.be/IKobsp1WszI). Part 2 of this notebook is on Mountain Car Problem which can be accessed from [here](https://github.com/sezan92/DQL/blob/master/Deep%20Q%20Learning%202.ipynb) .

# %% [markdown]
# ### The Concept of Experience Replay

# %% [markdown]
# One of the problems in Reinforcment learning is relearning Problem. That is , suppose, in the course of trial and error, one state $s_t$ comes only once or twice, and never comes back. What will happen? There is a chance that the Agent will forget that experience after some time- like us! . So we need to make the agent keep some kind of track of that memory as well. This problem was solved in 1993- yes 29 years ago!, by Long Ji lin. In his paper, ***Reinforcement Learning for Robots Using Neural Networks*** , he introduced the use of Experience Replay

# %% [markdown]
# ### Deep Q Learning

# %% [markdown]
# Vanilla Q learning works best where the state and actions of the agent is discrete . Like the following diagram , which is taken from [A painless Q Learning Tutorial](http://mnemstudio.org/path-finding-q-learning-tutorial.htm)

# %% [markdown]
# ![Painless](q_matrix5.gif)

# %% [markdown]
# Here the actions[along rows] are discrete as 0-5 and states [along columns] are also 0-5 . For state 0 the maximum Q value is 80 which is in column 4. So the best action will be 4. But in our case, the Cartpole game, the states aren't discrete. We had to discretize in the previous [version](https://github.com/sezan92/CartPoleRL/blob/master/CartPoleQLearning.ipynb).

# %% [markdown]
# Other than discretization , we cannot make the infinite states. So the best way is to train a neural network ,which given a state , gives output of Q value for each action. The agent will choose the action with maximum Q value and it will go on.

# %% [markdown]
# ![DQL](DQL.png)

# %% [markdown]
# Our Model

# %%
model = Sequential()
model.add(Dense(20,activation='relu',input_shape=(1,4)))
model.add(Dense(20,activation='relu'))
model.add(Dense(2,activation='linear'))
model.compile(loss='mse',optimizer=Adam(lr=0.01),)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1, 20)             100
# _________________________________________________________________
# dense_2 (Dense)              (None, 1, 20)             420
# _________________________________________________________________
# dense_3 (Dense)              (None, 1, 2)              42
# =================================================================
# Total params: 562
# Trainable params: 562
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Training

# %%
ep_list =[]
reward_list =[]  
for ep in range(num_episodes):
    s= env.reset()
    s=s.reshape((1,-1))
    rAll =0
    d = False
    j = 0
    for j in range(200):
        #time.sleep(0.01)
        #epsilon greedy. to choose random actions initially when Q is all zeros
        if np.random.random()< epsilon:
            a = np.random.randint(0,legal_actions)
            #epsilon = epsilon*epsilon_decay
        else:
            Q = model.predict(s.reshape(-1,s.shape[0],s.shape[1]))
            a =np.argmax(Q)
        new_s,r,d,_ = env.step(a)
        new_s = new_s.reshape((1,-1))
        rAll=rAll+r
        if show:
            env.render()
        if d:
            if rAll<195:
                r =-100
                experience = (s,r,a,new_s)
                memory.append(experience)
                print("Episode %d, Failed! Reward %d"%(ep,rAll))
                #break
            elif rAll>195:
                print("Episode %d, Passed! Reward %d"%(ep,rAll))
            ep_list.append(ep)
            reward_list.append(rAll)
            break
        
        experience = (s,r,a,new_s)
        memory.append(experience)
        if j==199:
            print("Reward %d after full episode"%(rAll))
            
        s = new_s
    batches=random.sample(memory,batch_size)
    states= np.array([batch[0] for batch in batches])
    rewards= np.array([batch[1] for batch in batches])
    actions= np.array([batch[2] for batch in batches])
    new_states= np.array([batch[3] for batch in batches])
    Qs =model.predict(states)
    new_Qs = model.predict(new_states)
    for i in range(len(rewards)):
        if rewards[i]==-100:
            Qs[i][0][actions[i]]=Qs[i][0][actions[i]]+ lr*(rewards[i]-Qs[i][0][actions[i]])
        else:
            Qs[i][0][actions[i]]= Qs[i][0][actions[i]]+ lr*(rewards[i]+gamma*np.max(new_Qs[i])-Qs[i][0][actions[i]])
    model.fit(states,Qs,verbose=0)
    epsilon=epsilon*epsilon_decay
env.close()
# Out:
# Episode 0, Failed! Reward 16
# Episode 1, Failed! Reward 14
# Episode 2, Failed! Reward 21
# Episode 3, Failed! Reward 34
# Episode 4, Failed! Reward 12
# Episode 5, Failed! Reward 13
# Episode 6, Failed! Reward 47
# Episode 7, Failed! Reward 35
# Episode 8, Failed! Reward 11
# Episode 9, Failed! Reward 88
# Episode 10, Failed! Reward 24
# Episode 11, Failed! Reward 9
# Episode 12, Failed! Reward 17
# Episode 13, Failed! Reward 20
# Episode 14, Failed! Reward 23
# Episode 15, Failed! Reward 19
# Episode 16, Failed! Reward 14
# Episode 17, Failed! Reward 24
# Episode 18, Failed! Reward 19
# Episode 19, Failed! Reward 12
# Episode 20, Failed! Reward 20
# Episode 21, Failed! Reward 20
# Episode 22, Failed! Reward 23
# Episode 23, Failed! Reward 22
# Episode 24, Failed! Reward 24
# Episode 25, Failed! Reward 14
# Episode 26, Failed! Reward 15
# Episode 27, Failed! Reward 38
# Episode 28, Failed! Reward 61
# Episode 29, Failed! Reward 44
# Episode 30, Failed! Reward 23
# Episode 31, Failed! Reward 18
# Episode 32, Failed! Reward 55
# Episode 33, Failed! Reward 16
# Episode 34, Failed! Reward 38
# Episode 35, Failed! Reward 29
# Episode 36, Failed! Reward 15
# Episode 37, Failed! Reward 42
# Episode 38, Failed! Reward 30
# Episode 39, Failed! Reward 27
# Episode 40, Failed! Reward 59
# Episode 41, Failed! Reward 21
# Episode 42, Failed! Reward 14
# Episode 43, Failed! Reward 22
# Episode 44, Failed! Reward 48
# Episode 45, Failed! Reward 12
# Episode 46, Failed! Reward 15
# Episode 47, Failed! Reward 12
# Episode 48, Failed! Reward 30
# Episode 49, Failed! Reward 33
# Episode 842, Failed! Reward 159
# Episode 843, Failed! Reward 165
# Episode 844, Failed! Reward 149
# Episode 845, Passed! Reward 196
# Episode 846, Failed! Reward 179
# Episode 847, Failed! Reward 149
# Episode 848, Failed! Reward 171
# Episode 849, Failed! Reward 162
# Episode 850, Failed! Reward 170
# Episode 851, Passed! Reward 200
# Episode 852, Failed! Reward 192
# Episode 853, Failed! Reward 185
# Episode 854, Passed! Reward 198
# Episode 855, Failed! Reward 164
# Episode 856, Failed! Reward 156
# Episode 857, Passed! Reward 197
# Episode 858, Passed! Reward 200
# Episode 859, Failed! Reward 177
# Episode 860, Passed! Reward 200
# Episode 861, Passed! Reward 200
# Episode 862, Passed! Reward 200
# Episode 863, Passed! Reward 200
# Episode 864, Passed! Reward 200
# Episode 865, Passed! Reward 200
# Episode 866, Passed! Reward 200
# Episode 867, Passed! Reward 200
# Episode 868, Passed! Reward 200
# Episode 869, Passed! Reward 200
# Episode 870, Passed! Reward 200
# Episode 871, Passed! Reward 200
# Episode 872, Passed! Reward 200
# Episode 873, Passed! Reward 200
# Episode 874, Passed! Reward 200
# Episode 875, Passed! Reward 200
# Episode 876, Passed! Reward 200
# Episode 877, Passed! Reward 200
# Episode 878, Passed! Reward 200
# Episode 879, Passed! Reward 200
# Episode 880, Passed! Reward 200
# Episode 881, Passed! Reward 200
# Episode 882, Passed! Reward 200
# Episode 883, Passed! Reward 200
# Episode 884, Passed! Reward 200
# Episode 885, Passed! Reward 200
# Episode 886, Passed! Reward 200
# Episode 887, Passed! Reward 200
# Episode 888, Passed! Reward 200
# Episode 889, Passed! Reward 200
# Episode 890, Passed! Reward 200
# Episode 891, Passed! Reward 200
# Episode 892, Passed! Reward 200
# Episode 893, Passed! Reward 200
# Episode 894, Passed! Reward 200
# Episode 895, Passed! Reward 200
# Episode 896, Passed! Reward 200
# Episode 897, Passed! Reward 200
# Episode 898, Passed! Reward 200
# Episode 899, Passed! Reward 200
# Episode 900, Passed! Reward 200
# Episode 901, Passed! Reward 200
# Episode 902, Passed! Reward 200
# Episode 903, Passed! Reward 200
# Episode 904, Passed! Reward 200
# Episode 905, Passed! Reward 200
# Episode 906, Passed! Reward 200
# Episode 907, Passed! Reward 200
# Episode 908, Passed! Reward 200
# Episode 909, Passed! Reward 200
# Episode 910, Passed! Reward 200
# Episode 911, Passed! Reward 200
# Episode 912, Passed! Reward 200
# Episode 913, Passed! Reward 200
# Episode 914, Passed! Reward 200
# Episode 915, Passed! Reward 200
# Episode 916, Passed! Reward 200
# Episode 917, Passed! Reward 200
# Episode 918, Passed! Reward 200
# Episode 919, Passed! Reward 200
# Episode 920, Passed! Reward 200
# Episode 921, Passed! Reward 200
# Episode 922, Passed! Reward 200
# Episode 923, Passed! Reward 200
# Episode 924, Passed! Reward 200
# Episode 925, Passed! Reward 200
# Episode 926, Passed! Reward 200
# Episode 927, Passed! Reward 200
# Episode 928, Passed! Reward 200
# Episode 929, Passed! Reward 200
# Episode 930, Passed! Reward 200
# Episode 931, Passed! Reward 200
# Episode 932, Passed! Reward 200
# Episode 933, Passed! Reward 200
# Episode 934, Passed! Reward 200
# Episode 935, Passed! Reward 200
# Episode 936, Passed! Reward 200
# Episode 937, Passed! Reward 200
# Episode 938, Passed! Reward 200
# Episode 939, Passed! Reward 200
# Episode 940, Passed! Reward 200
# Episode 941, Passed! Reward 200
# Episode 942, Passed! Reward 200
# Episode 943, Passed! Reward 200
# Episode 944, Passed! Reward 200
# Episode 945, Passed! Reward 200
# Episode 946, Passed! Reward 200
# Episode 947, Passed! Reward 200
# Episode 948, Passed! Reward 200
# Episode 949, Passed! Reward 200
# Episode 950, Passed! Reward 200
# Episode 951, Passed! Reward 200
# Episode 952, Passed! Reward 200
# Episode 953, Passed! Reward 200
# Episode 954, Passed! Reward 200
# Episode 955, Passed! Reward 200
# Episode 956, Passed! Reward 200
# Episode 957, Passed! Reward 200
# Episode 958, Passed! Reward 200
# Episode 959, Passed! Reward 200
# Episode 960, Passed! Reward 200
# Episode 961, Passed! Reward 200
# Episode 962, Passed! Reward 200
# Episode 963, Passed! Reward 200
# Episode 964, Passed! Reward 200
# Episode 965, Passed! Reward 200
# Episode 966, Passed! Reward 200
# Episode 967, Passed! Reward 200
# Episode 968, Passed! Reward 200
# Episode 969, Passed! Reward 200
# Episode 970, Passed! Reward 200
# Episode 971, Passed! Reward 200
# Episode 972, Passed! Reward 200
# Episode 973, Passed! Reward 200
# Episode 974, Passed! Reward 200
# Episode 975, Passed! Reward 200
# Episode 976, Passed! Reward 200
# Episode 977, Passed! Reward 200
# Episode 978, Passed! Reward 200
# Episode 979, Passed! Reward 200
# Episode 980, Passed! Reward 200
# Episode 981, Passed! Reward 200
# Episode 982, Passed! Reward 200
# Episode 983, Passed! Reward 200
# Episode 984, Passed! Reward 200
# Episode 985, Passed! Reward 200
# Episode 986, Passed! Reward 200
# Episode 987, Passed! Reward 200
# Episode 988, Passed! Reward 200
# Episode 989, Passed! Reward 200
# Episode 990, Passed! Reward 200
# Episode 991, Passed! Reward 200
# Episode 992, Passed! Reward 200
# Episode 993, Passed! Reward 200
# Episode 994, Passed! Reward 200
# Episode 995, Passed! Reward 200
# Episode 996, Passed! Reward 200
# Episode 997, Passed! Reward 200
# Episode 998, Passed! Reward 200
# Episode 999, Passed! Reward 200

# %% [markdown]
# #### Plot of Episodes vs Reward

# %% [markdown]
# Deep Q Learning

# %% [markdown]
# ![DQL](Reward_vs_Episode_DL_lr_0.500000_eps_1000_CartPole.jpg)

# %% [markdown]
# Plot for Vanilla ```Q Learning```

# %% [markdown]
# ![QLearning](Reward_vs_Episode_QL_lr_0.500000_eps_1000_CartPole.jpg)

# %% [markdown]
# The above two pictures show that Deep Q Network reached the highest points faster than traditional Q Learning Algorithm

# %% [markdown]
# ## Further Improvement

# %% [markdown]
# You can try and give some trials with different architectures, parameters and hyperparameters for improvement.
